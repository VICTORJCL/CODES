# %% [markdown]
# # Visualizando Tabelas com pandas

# %% [markdown]
# ### Visaulização básica no jupyter

# %%
import pandas as pd

data = {'Nome': ['Adriano', 'Rodrigo', 'Juliano', 'Mateus', 'Luiza', 'Rodrigo', 'Ayres', 'Aninha'],
		'Sobrenome': ['Soares', 'Tadewald', 'Faccioni', 'Kienzle', 'Cherobini', 'Vanzelotti', 'Júnior', 'Tadewald'],}

df = pd.DataFrame(data)

df
# Out:
#       Nome   Sobrenome
# 0  Adriano      Soares
# 1  Rodrigo    Tadewald
# 2  Juliano    Faccioni
# 3   Mateus     Kienzle
# 4    Luiza   Cherobini
# 5  Rodrigo  Vanzelotti
# 6    Ayres      Júnior
# 7   Aninha    Tadewald

# %% [markdown]
# ### Visualização os primeiros valores (.head)

# %%
import pandas as pd
  
data = {'Nome': ['Adriano', 'Rodrigo', 'Juliano', 'Mateus', 'Luiza', 'Rodrigo', 'Ayres', 'Aninha'],
        'Sobrenome': ['Soares', 'Tadewald', 'Faccioni', 'Kienzle', 'Cherobini', 'Vanzelotti', 'Júnior', 'Tadewald'],}
df = pd.DataFrame(data)
  
df.head()
# Out:
#       Nome  Sobrenome
# 0  Adriano     Soares
# 1  Rodrigo   Tadewald
# 2  Juliano   Faccioni
# 3   Mateus    Kienzle
# 4    Luiza  Cherobini

# %%
df.head(2)
# Out:
#       Nome Sobrenome
# 0  Adriano    Soares
# 1  Rodrigo  Tadewald

# %% [markdown]
# ### Visualização os últimos valores (.tail)

# %%
import pandas as pd

data = {'Nome': ['Adriano', 'Rodrigo', 'Juliano', 'Mateus', 'Luiza', 'Rodrigo', 'Ayres', 'Aninha'],
        'Sobrenome': ['Soares', 'Tadewald', 'Faccioni', 'Kienzle', 'Cherobini', 'Vanzelotti', 'Júnior', 'Tadewald'],}

df = pd.DataFrame(data)

df.tail()
# Out:
#       Nome   Sobrenome
# 3   Mateus     Kienzle
# 4    Luiza   Cherobini
# 5  Rodrigo  Vanzelotti
# 6    Ayres      Júnior
# 7   Aninha    Tadewald

# %%
df.tail(3)
# Out:
#       Nome   Sobrenome
# 5  Rodrigo  Vanzelotti
# 6    Ayres      Júnior
# 7   Aninha    Tadewald

# %% [markdown]
# ### Visualizando tabelas maiores no Jupyter (display.max_rows)

# %%
import pandas as pd

tabela_vendas = pd.read_csv('datasets/vendas.csv', sep=';', decimal=',')
pd.set_option('display.max_rows', 50)
tabela_vendas.head(50)
# Out:
#                           data  id_venda         filial            vendedor  \
# 0   2023-01-12 07:42:38.311304         1         Canoas       Luis Fernando
# 1   2023-01-12 08:21:37.427917         2  Florianópolis  Claudia dos Santos
# 2   2023-01-12 08:27:36.903347         3      São Paulo       Cassia Moraes
# 3   2023-01-12 09:32:38.748455         4  Florianópolis        Mario Sérgio
# 4   2023-01-12 11:01:38.047889         5         Canoas       Luis Fernando
# 5   2023-01-12 14:41:39.235334         6         Canoas     Carlos Henrique
# 6   2023-01-13 06:40:39.161308         7  Florianópolis  Claudia dos Santos
# %% [markdown]
# ### Estilizando a visualização

# %% [markdown]
# #### Formatando floats

# %%
import pandas as pd
import numpy as np

df_tempo = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2023-01-01", periods=10),
                          columns=["Porto Alegre", "São Paulo"])
df_tempo.style.format(precision=3, decimal=",")
# Out:
# <style type="text/css">
# </style>
# <table id="T_362fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_362fd_level0_col0" class="col_heading level0 col0" >Porto Alegre</th>
#       <th id="T_362fd_level0_col1" class="col_heading level0 col1" >São Paulo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_362fd_level0_row0" class="row_heading level0 row0" >2023-01-01 00:00:00</th>
#       <td id="T_362fd_row0_col0" class="data row0 col0" >4,744</td>
#       <td id="T_362fd_row0_col1" class="data row0 col1" >4,400</td>
#     </tr>
#     <tr>
#       <th id="T_362fd_level0_row1" class="row_heading level0 row1" >2023-01-02 00:00:00</th>
#       <td id="T_362fd_row1_col0" class="data row1 col0" >2,205</td>
#       <td id="T_362fd_row1_col1" class="data row1 col1" >0,896</td>
#     </tr>
#     <tr>
#       <th id="T_362fd_level0_row2" class="row_heading level0 row2" >2023-01-03 00:00:00</th>
#       <td id="T_362fd_row2_col0" class="data row2 col0" >1,541</td>
#       <td id="T_362fd_row2_col1" class="data row2 col1" >4,253</td>
#     </tr>
#     <tr>
#       <th id="T_362fd_level0_row3" class="row_heading level0 row3" >2023-01-04 00:00:00</th>
#       <td id="T_362fd_row3_col0" class="data row3 col0" >0,926</td>
#       <td id="T_362fd_row3_col1" class="data row3 col1" >2,190</td>
#     </tr>
#     <tr>
#       <th id="T_362fd_level0_row4" class="row_heading level0 row4" >2023-01-05 00:00:00</th>
#       <td id="T_362fd_row4_col0" class="data row4 col0" >4,173</td>
#       <td id="T_362fd_row4_col1" class="data row4 col1" >1,142</td>
#     </tr>
#     <tr>
#       <th id="T_362fd_level0_row5" class="row_heading level0 row5" >2023-01-06 00:00:00</th>
#       <td id="T_362fd_row5_col0" class="data row5 col0" >1,675</td>
#       <td id="T_362fd_row5_col1" class="data row5 col1" >3,656</td>
#     </tr>
#     <tr>
#       <th id="T_362fd_level0_row6" class="row_heading level0 row6" >2023-01-07 00:00:00</th>
#       <td id="T_362fd_row6_col0" class="data row6 col0" >4,705</td>
#       <td id="T_362fd_row6_col1" class="data row6 col1" >3,729</td>
#     </tr>
#     <tr>
#       <th id="T_362fd_level0_row7" class="row_heading level0 row7" >2023-01-08 00:00:00</th>
#       <td id="T_362fd_row7_col0" class="data row7 col0" >0,586</td>
#       <td id="T_362fd_row7_col1" class="data row7 col1" >1,563</td>
#     </tr>
#     <tr>
#       <th id="T_362fd_level0_row8" class="row_heading level0 row8" >2023-01-09 00:00:00</th>
#       <td id="T_362fd_row8_col0" class="data row8 col0" >4,046</td>
#       <td id="T_362fd_row8_col1" class="data row8 col1" >2,662</td>
#     </tr>
#     <tr>
#       <th id="T_362fd_level0_row9" class="row_heading level0 row9" >2023-01-10 00:00:00</th>
#       <td id="T_362fd_row9_col0" class="data row9 col0" >3,323</td>
#       <td id="T_362fd_row9_col1" class="data row9 col1" >4,944</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Estilizando colunas

# %%
df_tempo.style.format_index(str.upper, axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9a393">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a393_level0_col0" class="col_heading level0 col0" >PORTO ALEGRE</th>
#       <th id="T_9a393_level0_col1" class="col_heading level0 col1" >SÃO PAULO</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a393_level0_row0" class="row_heading level0 row0" >2023-01-01 00:00:00</th>
#       <td id="T_9a393_row0_col0" class="data row0 col0" >4.743956</td>
#       <td id="T_9a393_row0_col1" class="data row0 col1" >4.399734</td>
#     </tr>
#     <tr>
#       <th id="T_9a393_level0_row1" class="row_heading level0 row1" >2023-01-02 00:00:00</th>
#       <td id="T_9a393_row1_col0" class="data row1 col0" >2.205050</td>
#       <td id="T_9a393_row1_col1" class="data row1 col1" >0.895875</td>
#     </tr>
#     <tr>
#       <th id="T_9a393_level0_row2" class="row_heading level0 row2" >2023-01-03 00:00:00</th>
#       <td id="T_9a393_row2_col0" class="data row2 col0" >1.540781</td>
#       <td id="T_9a393_row2_col1" class="data row2 col1" >4.252555</td>
#     </tr>
#     <tr>
#       <th id="T_9a393_level0_row3" class="row_heading level0 row3" >2023-01-04 00:00:00</th>
#       <td id="T_9a393_row3_col0" class="data row3 col0" >0.926312</td>
#       <td id="T_9a393_row3_col1" class="data row3 col1" >2.190103</td>
#     </tr>
#     <tr>
#       <th id="T_9a393_level0_row4" class="row_heading level0 row4" >2023-01-05 00:00:00</th>
#       <td id="T_9a393_row4_col0" class="data row4 col0" >4.173261</td>
#       <td id="T_9a393_row4_col1" class="data row4 col1" >1.141685</td>
#     </tr>
#     <tr>
#       <th id="T_9a393_level0_row5" class="row_heading level0 row5" >2023-01-06 00:00:00</th>
#       <td id="T_9a393_row5_col0" class="data row5 col0" >1.674765</td>
#       <td id="T_9a393_row5_col1" class="data row5 col1" >3.656205</td>
#     </tr>
#     <tr>
#       <th id="T_9a393_level0_row6" class="row_heading level0 row6" >2023-01-07 00:00:00</th>
#       <td id="T_9a393_row6_col0" class="data row6 col0" >4.705167</td>
#       <td id="T_9a393_row6_col1" class="data row6 col1" >3.728604</td>
#     </tr>
#     <tr>
#       <th id="T_9a393_level0_row7" class="row_heading level0 row7" >2023-01-08 00:00:00</th>
#       <td id="T_9a393_row7_col0" class="data row7 col0" >0.586014</td>
#       <td id="T_9a393_row7_col1" class="data row7 col1" >1.563346</td>
#     </tr>
#     <tr>
#       <th id="T_9a393_level0_row8" class="row_heading level0 row8" >2023-01-09 00:00:00</th>
#       <td id="T_9a393_row8_col0" class="data row8 col0" >4.046439</td>
#       <td id="T_9a393_row8_col1" class="data row8 col1" >2.662407</td>
#     </tr>
#     <tr>
#       <th id="T_9a393_level0_row9" class="row_heading level0 row9" >2023-01-10 00:00:00</th>
#       <td id="T_9a393_row9_col0" class="data row9 col0" >3.322670</td>
#       <td id="T_9a393_row9_col1" class="data row9 col1" >4.944406</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Estilizando index

# %%
df_tempo.style.format_index(lambda v: v.strftime("%d/%m/%Y"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_9817c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9817c_level0_col0" class="col_heading level0 col0" >Porto Alegre</th>
#       <th id="T_9817c_level0_col1" class="col_heading level0 col1" >São Paulo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9817c_level0_row0" class="row_heading level0 row0" >01/01/2023</th>
#       <td id="T_9817c_row0_col0" class="data row0 col0" >4.743956</td>
#       <td id="T_9817c_row0_col1" class="data row0 col1" >4.399734</td>
#     </tr>
#     <tr>
#       <th id="T_9817c_level0_row1" class="row_heading level0 row1" >02/01/2023</th>
#       <td id="T_9817c_row1_col0" class="data row1 col0" >2.205050</td>
#       <td id="T_9817c_row1_col1" class="data row1 col1" >0.895875</td>
#     </tr>
#     <tr>
#       <th id="T_9817c_level0_row2" class="row_heading level0 row2" >03/01/2023</th>
#       <td id="T_9817c_row2_col0" class="data row2 col0" >1.540781</td>
#       <td id="T_9817c_row2_col1" class="data row2 col1" >4.252555</td>
#     </tr>
#     <tr>
#       <th id="T_9817c_level0_row3" class="row_heading level0 row3" >04/01/2023</th>
#       <td id="T_9817c_row3_col0" class="data row3 col0" >0.926312</td>
#       <td id="T_9817c_row3_col1" class="data row3 col1" >2.190103</td>
#     </tr>
#     <tr>
#       <th id="T_9817c_level0_row4" class="row_heading level0 row4" >05/01/2023</th>
#       <td id="T_9817c_row4_col0" class="data row4 col0" >4.173261</td>
#       <td id="T_9817c_row4_col1" class="data row4 col1" >1.141685</td>
#     </tr>
#     <tr>
#       <th id="T_9817c_level0_row5" class="row_heading level0 row5" >06/01/2023</th>
#       <td id="T_9817c_row5_col0" class="data row5 col0" >1.674765</td>
#       <td id="T_9817c_row5_col1" class="data row5 col1" >3.656205</td>
#     </tr>
#     <tr>
#       <th id="T_9817c_level0_row6" class="row_heading level0 row6" >07/01/2023</th>
#       <td id="T_9817c_row6_col0" class="data row6 col0" >4.705167</td>
#       <td id="T_9817c_row6_col1" class="data row6 col1" >3.728604</td>
#     </tr>
#     <tr>
#       <th id="T_9817c_level0_row7" class="row_heading level0 row7" >08/01/2023</th>
#       <td id="T_9817c_row7_col0" class="data row7 col0" >0.586014</td>
#       <td id="T_9817c_row7_col1" class="data row7 col1" >1.563346</td>
#     </tr>
#     <tr>
#       <th id="T_9817c_level0_row8" class="row_heading level0 row8" >09/01/2023</th>
#       <td id="T_9817c_row8_col0" class="data row8 col0" >4.046439</td>
#       <td id="T_9817c_row8_col1" class="data row8 col1" >2.662407</td>
#     </tr>
#     <tr>
#       <th id="T_9817c_level0_row9" class="row_heading level0 row9" >10/01/2023</th>
#       <td id="T_9817c_row9_col0" class="data row9 col0" >3.322670</td>
#       <td id="T_9817c_row9_col1" class="data row9 col1" >4.944406</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Adicionando título

# %%
df_tempo.style.set_caption('Condição do tempo')
# Out:
# <style type="text/css">
# </style>
# <table id="T_181de">
#   <caption>Condição do tempo</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_181de_level0_col0" class="col_heading level0 col0" >Porto Alegre</th>
#       <th id="T_181de_level0_col1" class="col_heading level0 col1" >São Paulo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_181de_level0_row0" class="row_heading level0 row0" >2023-01-01 00:00:00</th>
#       <td id="T_181de_row0_col0" class="data row0 col0" >4.743956</td>
#       <td id="T_181de_row0_col1" class="data row0 col1" >4.399734</td>
#     </tr>
#     <tr>
#       <th id="T_181de_level0_row1" class="row_heading level0 row1" >2023-01-02 00:00:00</th>
#       <td id="T_181de_row1_col0" class="data row1 col0" >2.205050</td>
#       <td id="T_181de_row1_col1" class="data row1 col1" >0.895875</td>
#     </tr>
#     <tr>
#       <th id="T_181de_level0_row2" class="row_heading level0 row2" >2023-01-03 00:00:00</th>
#       <td id="T_181de_row2_col0" class="data row2 col0" >1.540781</td>
#       <td id="T_181de_row2_col1" class="data row2 col1" >4.252555</td>
#     </tr>
#     <tr>
#       <th id="T_181de_level0_row3" class="row_heading level0 row3" >2023-01-04 00:00:00</th>
#       <td id="T_181de_row3_col0" class="data row3 col0" >0.926312</td>
#       <td id="T_181de_row3_col1" class="data row3 col1" >2.190103</td>
#     </tr>
#     <tr>
#       <th id="T_181de_level0_row4" class="row_heading level0 row4" >2023-01-05 00:00:00</th>
#       <td id="T_181de_row4_col0" class="data row4 col0" >4.173261</td>
#       <td id="T_181de_row4_col1" class="data row4 col1" >1.141685</td>
#     </tr>
#     <tr>
#       <th id="T_181de_level0_row5" class="row_heading level0 row5" >2023-01-06 00:00:00</th>
#       <td id="T_181de_row5_col0" class="data row5 col0" >1.674765</td>
#       <td id="T_181de_row5_col1" class="data row5 col1" >3.656205</td>
#     </tr>
#     <tr>
#       <th id="T_181de_level0_row6" class="row_heading level0 row6" >2023-01-07 00:00:00</th>
#       <td id="T_181de_row6_col0" class="data row6 col0" >4.705167</td>
#       <td id="T_181de_row6_col1" class="data row6 col1" >3.728604</td>
#     </tr>
#     <tr>
#       <th id="T_181de_level0_row7" class="row_heading level0 row7" >2023-01-08 00:00:00</th>
#       <td id="T_181de_row7_col0" class="data row7 col0" >0.586014</td>
#       <td id="T_181de_row7_col1" class="data row7 col1" >1.563346</td>
#     </tr>
#     <tr>
#       <th id="T_181de_level0_row8" class="row_heading level0 row8" >2023-01-09 00:00:00</th>
#       <td id="T_181de_row8_col0" class="data row8 col0" >4.046439</td>
#       <td id="T_181de_row8_col1" class="data row8 col1" >2.662407</td>
#     </tr>
#     <tr>
#       <th id="T_181de_level0_row9" class="row_heading level0 row9" >2023-01-10 00:00:00</th>
#       <td id="T_181de_row9_col0" class="data row9 col0" >3.322670</td>
#       <td id="T_181de_row9_col1" class="data row9 col1" >4.944406</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Adicionando gradiente (formatação condicional)

# %%
df_tempo.style.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlGnBu")
# Out:
# <style type="text/css">
# #T_96c78_row0_col0 {
#   background-color: #172976;
#   color: #f1f1f1;
# }
# #T_96c78_row0_col1 {
#   background-color: #243c98;
#   color: #f1f1f1;
# }
# #T_96c78_row1_col0 {
#   background-color: #a9ddb7;
#   color: #000000;
# }
# #T_96c78_row1_col1, #T_96c78_row3_col0, #T_96c78_row7_col0 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_96c78_row2_col0 {
#   background-color: #eaf7b1;
#   color: #000000;
# }
# #T_96c78_row2_col1 {
#   background-color: #24489d;
#   color: #f1f1f1;
# }
# #T_96c78_row3_col1 {
#   background-color: #abdeb7;
#   color: #000000;
# }
# #T_96c78_row4_col0 {
#   background-color: #234fa1;
#   color: #f1f1f1;
# }
# #T_96c78_row4_col1 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_96c78_row5_col0 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_96c78_row5_col1 {
#   background-color: #1f82b9;
#   color: #f1f1f1;
# }
# #T_96c78_row6_col0 {
#   background-color: #182a7a;
#   color: #f1f1f1;
# }
# #T_96c78_row6_col1 {
#   background-color: #1f7ab5;
#   color: #f1f1f1;
# }
# #T_96c78_row7_col1 {
#   background-color: #e8f6b1;
#   color: #000000;
# }
# #T_96c78_row8_col0 {
#   background-color: #225aa6;
#   color: #f1f1f1;
# }
# #T_96c78_row8_col1 {
#   background-color: #6bc6be;
#   color: #000000;
# }
# #T_96c78_row9_col0 {
#   background-color: #2a9ec1;
#   color: #f1f1f1;
# }
# #T_96c78_row9_col1 {
#   background-color: #0b1f5e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_96c78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96c78_level0_col0" class="col_heading level0 col0" >Porto Alegre</th>
#       <th id="T_96c78_level0_col1" class="col_heading level0 col1" >São Paulo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96c78_level0_row0" class="row_heading level0 row0" >2023-01-01 00:00:00</th>
#       <td id="T_96c78_row0_col0" class="data row0 col0" >4.743956</td>
#       <td id="T_96c78_row0_col1" class="data row0 col1" >4.399734</td>
#     </tr>
#     <tr>
#       <th id="T_96c78_level0_row1" class="row_heading level0 row1" >2023-01-02 00:00:00</th>
#       <td id="T_96c78_row1_col0" class="data row1 col0" >2.205050</td>
#       <td id="T_96c78_row1_col1" class="data row1 col1" >0.895875</td>
#     </tr>
#     <tr>
#       <th id="T_96c78_level0_row2" class="row_heading level0 row2" >2023-01-03 00:00:00</th>
#       <td id="T_96c78_row2_col0" class="data row2 col0" >1.540781</td>
#       <td id="T_96c78_row2_col1" class="data row2 col1" >4.252555</td>
#     </tr>
#     <tr>
#       <th id="T_96c78_level0_row3" class="row_heading level0 row3" >2023-01-04 00:00:00</th>
#       <td id="T_96c78_row3_col0" class="data row3 col0" >0.926312</td>
#       <td id="T_96c78_row3_col1" class="data row3 col1" >2.190103</td>
#     </tr>
#     <tr>
#       <th id="T_96c78_level0_row4" class="row_heading level0 row4" >2023-01-05 00:00:00</th>
#       <td id="T_96c78_row4_col0" class="data row4 col0" >4.173261</td>
#       <td id="T_96c78_row4_col1" class="data row4 col1" >1.141685</td>
#     </tr>
#     <tr>
#       <th id="T_96c78_level0_row5" class="row_heading level0 row5" >2023-01-06 00:00:00</th>
#       <td id="T_96c78_row5_col0" class="data row5 col0" >1.674765</td>
#       <td id="T_96c78_row5_col1" class="data row5 col1" >3.656205</td>
#     </tr>
#     <tr>
#       <th id="T_96c78_level0_row6" class="row_heading level0 row6" >2023-01-07 00:00:00</th>
#       <td id="T_96c78_row6_col0" class="data row6 col0" >4.705167</td>
#       <td id="T_96c78_row6_col1" class="data row6 col1" >3.728604</td>
#     </tr>
#     <tr>
#       <th id="T_96c78_level0_row7" class="row_heading level0 row7" >2023-01-08 00:00:00</th>
#       <td id="T_96c78_row7_col0" class="data row7 col0" >0.586014</td>
#       <td id="T_96c78_row7_col1" class="data row7 col1" >1.563346</td>
#     </tr>
#     <tr>
#       <th id="T_96c78_level0_row8" class="row_heading level0 row8" >2023-01-09 00:00:00</th>
#       <td id="T_96c78_row8_col0" class="data row8 col0" >4.046439</td>
#       <td id="T_96c78_row8_col1" class="data row8 col1" >2.662407</td>
#     </tr>
#     <tr>
#       <th id="T_96c78_level0_row9" class="row_heading level0 row9" >2023-01-10 00:00:00</th>
#       <td id="T_96c78_row9_col0" class="data row9 col0" >3.322670</td>
#       <td id="T_96c78_row9_col1" class="data row9 col1" >4.944406</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Juntando tudo

# %%
def condição_chuva(v):
    if v < 1.75:
        return "Seco"
    elif v < 2.75:
        return "Chuva"
    return "Chuva Forte"

def embelezar(styler):
    styler.set_caption("Condição do tempo")
    styler.format(condição_chuva)
    styler.format_index(lambda v: v.strftime("%d/%m/%Y"))
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlGnBu")
    return styler

df_tempo.style.pipe(embelezar)
# Out:
# <style type="text/css">
# #T_9bc2c_row0_col0 {
#   background-color: #172976;
#   color: #f1f1f1;
# }
# #T_9bc2c_row0_col1 {
#   background-color: #243c98;
#   color: #f1f1f1;
# }
# #T_9bc2c_row1_col0 {
#   background-color: #a9ddb7;
#   color: #000000;
# }
# #T_9bc2c_row1_col1, #T_9bc2c_row3_col0, #T_9bc2c_row7_col0 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_9bc2c_row2_col0 {
#   background-color: #eaf7b1;
#   color: #000000;
# }
# #T_9bc2c_row2_col1 {
#   background-color: #24489d;
#   color: #f1f1f1;
# }
# #T_9bc2c_row3_col1 {
#   background-color: #abdeb7;
#   color: #000000;
# }
# #T_9bc2c_row4_col0 {
#   background-color: #234fa1;
#   color: #f1f1f1;
# }
# #T_9bc2c_row4_col1 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_9bc2c_row5_col0 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_9bc2c_row5_col1 {
#   background-color: #1f82b9;
#   color: #f1f1f1;
# }
# #T_9bc2c_row6_col0 {
#   background-color: #182a7a;
#   color: #f1f1f1;
# }
# #T_9bc2c_row6_col1 {
#   background-color: #1f7ab5;
#   color: #f1f1f1;
# }
# #T_9bc2c_row7_col1 {
#   background-color: #e8f6b1;
#   color: #000000;
# }
# #T_9bc2c_row8_col0 {
#   background-color: #225aa6;
#   color: #f1f1f1;
# }
# #T_9bc2c_row8_col1 {
#   background-color: #6bc6be;
#   color: #000000;
# }
# #T_9bc2c_row9_col0 {
#   background-color: #2a9ec1;
#   color: #f1f1f1;
# }
# #T_9bc2c_row9_col1 {
#   background-color: #0b1f5e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9bc2c">
#   <caption>Condição do tempo</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bc2c_level0_col0" class="col_heading level0 col0" >Porto Alegre</th>
#       <th id="T_9bc2c_level0_col1" class="col_heading level0 col1" >São Paulo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bc2c_level0_row0" class="row_heading level0 row0" >01/01/2023</th>
#       <td id="T_9bc2c_row0_col0" class="data row0 col0" >Chuva Forte</td>
#       <td id="T_9bc2c_row0_col1" class="data row0 col1" >Chuva Forte</td>
#     </tr>
#     <tr>
#       <th id="T_9bc2c_level0_row1" class="row_heading level0 row1" >02/01/2023</th>
#       <td id="T_9bc2c_row1_col0" class="data row1 col0" >Chuva</td>
#       <td id="T_9bc2c_row1_col1" class="data row1 col1" >Seco</td>
#     </tr>
#     <tr>
#       <th id="T_9bc2c_level0_row2" class="row_heading level0 row2" >03/01/2023</th>
#       <td id="T_9bc2c_row2_col0" class="data row2 col0" >Seco</td>
#       <td id="T_9bc2c_row2_col1" class="data row2 col1" >Chuva Forte</td>
#     </tr>
#     <tr>
#       <th id="T_9bc2c_level0_row3" class="row_heading level0 row3" >04/01/2023</th>
#       <td id="T_9bc2c_row3_col0" class="data row3 col0" >Seco</td>
#       <td id="T_9bc2c_row3_col1" class="data row3 col1" >Chuva</td>
#     </tr>
#     <tr>
#       <th id="T_9bc2c_level0_row4" class="row_heading level0 row4" >05/01/2023</th>
#       <td id="T_9bc2c_row4_col0" class="data row4 col0" >Chuva Forte</td>
#       <td id="T_9bc2c_row4_col1" class="data row4 col1" >Seco</td>
#     </tr>
#     <tr>
#       <th id="T_9bc2c_level0_row5" class="row_heading level0 row5" >06/01/2023</th>
#       <td id="T_9bc2c_row5_col0" class="data row5 col0" >Seco</td>
#       <td id="T_9bc2c_row5_col1" class="data row5 col1" >Chuva Forte</td>
#     </tr>
#     <tr>
#       <th id="T_9bc2c_level0_row6" class="row_heading level0 row6" >07/01/2023</th>
#       <td id="T_9bc2c_row6_col0" class="data row6 col0" >Chuva Forte</td>
#       <td id="T_9bc2c_row6_col1" class="data row6 col1" >Chuva Forte</td>
#     </tr>
#     <tr>
#       <th id="T_9bc2c_level0_row7" class="row_heading level0 row7" >08/01/2023</th>
#       <td id="T_9bc2c_row7_col0" class="data row7 col0" >Seco</td>
#       <td id="T_9bc2c_row7_col1" class="data row7 col1" >Seco</td>
#     </tr>
#     <tr>
#       <th id="T_9bc2c_level0_row8" class="row_heading level0 row8" >09/01/2023</th>
#       <td id="T_9bc2c_row8_col0" class="data row8 col0" >Chuva Forte</td>
#       <td id="T_9bc2c_row8_col1" class="data row8 col1" >Chuva</td>
#     </tr>
#     <tr>
#       <th id="T_9bc2c_level0_row9" class="row_heading level0 row9" >10/01/2023</th>
#       <td id="T_9bc2c_row9_col0" class="data row9 col0" >Chuva Forte</td>
#       <td id="T_9bc2c_row9_col1" class="data row9 col1" >Chuva Forte</td>
#     </tr>
#   </tbody>
# </table>
